# %%
####     //      Import/Install packages/REST API       \\       ####
# Default packages
import time
import csv
import os
import json

# Preinstalled packages
import requests
import pandas as pd


# Define desired wd, where I want to save my .csv files
desired_wd = '/Users/jenskoning/Documents/Python_projects/dsr_media_nlp/dsr_media_nlp/Script/'
os.chdir(desired_wd)

# URL of our News API
base_url = 'https://api.newscatcherapi.com/v2/search'

# My API key
X_API_KEY = 'uPGwd9h_DeqHKvxrDL5z9fu3t1Mc9rroBabtvX0iOuE'

# %%
####     //      Query Data       \\       ####
# Put my API key to headers in order to be authorized to perform a call
headers = {'x-api-key': X_API_KEY}

params = [
    {
    'q': 'Digital Silk Road AND DSR',
    'lang': 'en',
    'to_rank': 10000,
    'page_size': 100,
    'from': '3 years ago', 
    'page': 1
    },
    {
    'q': 'Digital Silk Road AND China',
    'lang': 'en',
    'to_rank': 10000,
    'page_size': 100,
    'from': '3 years ago', 
    'page': 1
    },
    {
    'q': 'Digital Silk Road AND Malaysia',
    'lang': 'en',
    'to_rank': 10000,
    'page_size': 100,
    'from': '3 years ago', 
    'page': 1
    },
    {
    'q': 'Digital Silk Road AND Indonesia',
    'lang': 'en',
    'to_rank': 10000,
    'page_size': 100,
    'from': '3 years ago', 
    'page': 1
    },
    {
    'q': 'Digital Silk Road AND Philippines',
    'lang': 'en',
    'to_rank': 10000,
    'page_size': 100,
    'from': '3 years ago', 
    'page': 1
    },
    {
    'q': 'Digital Silk Road AND Geopolitics',
    'lang': 'en',
    'to_rank': 10000,
    'page_size': 100,
    'from': '3 years ago', 
    'page': 1
    }
]

# Make a simple call with both headers and params
response = requests.get(base_url, headers=headers, params=params)

# Encode received results
results = json.loads(response.text.encode())
if response.status_code == 200:
    print('Done')
else:
    print(results)
    print('ERROR: API call failed.')
# Out:
# Done

# %%
####     //      Convert into pandas table       \\       ####
pandas_table = pd.DataFrame(results['articles'])
display(pandas_table)
# Out:
#                                                 title            author  \
# 0   Investigating responses to China's Digital Sil...     David Bradley
# 1   Xi Jinping's Vision For The Middle East – Anal...  Hudson Institute
# 2   As decade-old 'Belt and Road' sags, China evol...
# 3   As decade-old 'Belt and Road' sags, China evol...          ANI 12th
# 4   As decade-old 'Belt and Road' sags, China evol...               ANI
# ..                                                ...               ...
# 64  Assessing China's Digital Silk Road: A Transfo...   Amelia Cheatham
# 65  China's Digital Silk Road Initiative: A Boon f...              None
# 66  China's Digital Silk Road Grows With 5G in the...     Sophie Zinser
# 67  White House unveils new tech initiative as tec...           samgush
# 68  China is winning the war for global tech domin...              None
#
#          published_date published_date_precision  \
# 0   2023-09-01 16:52:09                     full
# 1   2023-07-21 01:02:50                     full
# 2   2023-06-12 11:45:00         timezone unknown
# 3   2023-06-12 10:27:00                     full
# 4   2023-06-12 10:15:22                     full
# ..                  ...                      ...
# 64  2020-12-18 15:38:29                     full
# 65  2020-12-17 07:15:00         timezone unknown
# 66  2020-12-15 20:00:00         timezone unknown
# 67  2020-10-17 16:14:12                     full
# 68  2020-10-04 20:00:08                     full
#
#                                                  link           clean_url  \
# 0   https://phys.org/news/2023-09-responses-china-...            phys.org
# 1   https://api.follow.it/track-rss-story-click/v3...           follow.it
# 2   https://www.aninews.in/news/world/asia/as-deca...          aninews.in
# 3   https://www.bignewsnetwork.com/news/273862107/...  bignewsnetwork.com
# 4   https://www.devdiscourse.com/article/internati...    devdiscourse.com
# ..                                                ...                 ...
# 64  https://www.cfr.org/blog/assessing-chinas-digi...             cfr.org
# 65  https://thediplomat.com/2020/12/chinas-digital...     thediplomat.com
# 66  https://thediplomat.com/2020/12/chinas-digital...     thediplomat.com
# 67  https://www.techspot.com/news/87161-white-hous...        techspot.com
# 68  https://thehill.com/opinion/technology/518773-...         thehill.com
#
#                                               excerpt  \
# 0   From the second century to the middle of the 1...
# 1   By Yair Albeck Chinese leader Xi Jinping clear...
# 2   The BRI became a blue-ribbon project for Xi. T...
# 3   When China President Xi Jinping floated the Be...
# 4   The BRI became a blue-ribbon project for Xi. T...
# ..                                                ...
# 64  As part of China's massive Belt and Road Initi...
# 65  Some observers worry that it will equip author...
# 66  Huawei and other Chinese firms continue to mak...
# 67  The White House proposition suggests that tech...
# 68  Beijing wants to define the standards of impor...
#
#                                               summary              rights  \
# 0   Credit: Unsplash/CC0 Public Domain \n \n \n\n\...            phys.org
# 1   By Yair Albeck\n\n\nChinese leader Xi Jinping ...           follow.it
# 2   Hong Kong, June 12 (ANI): When \n\n's Presiden...          aninews.in
# 3   ANI \n12th June 2023, 20:27 GMT+10\nHong Kong,...  bignewsnetwork.com
# 4   When China's President Xi Jinping floated the ...    devdiscourse.com
# ..                                                ...                 ...
# 64  As part of China's massive Belt and Road Initi...             cfr.org
# 65  AdvertisementAs part of China's massive Belt a...     thediplomat.com
# 66  In this Oct. 14, 2020, file photo, a man weari...     thediplomat.com
# 67  The White House proposition suggests that tech...        techspot.com
# 68  When the United Kingdom announced in July that...         thehill.com
#
#     rank  topic country language  \
# 0    622   news      GB       en
# 1   2292   news      IT       en
# 2   8311  world      IN       en
# 3   5608   news      US       en
# 4   8841  world      IN       en
# ..   ...    ...     ...      ...
# 64  1830   news      US       en
# 65  2310   news      ID       en
# 66  2310   news      ID       en
# 67  2780   news      US       en
# 68   570   tech      US       en
#
#                                               authors  \
# 0                                       David Bradley
# 1   Amna Ansar,Hudson Institute,Prosperity,Sheikh ...
# 2
# 3                                            ANI 12th
# 4                                                 ANI
# ..                                                ...
# 64  Amelia Cheatham,Claire Felter,Lindsay Maizland...
# 65                                               None
# 66                                      Sophie Zinser
# 67                                    samgush,samgush
# 68                                               None
#
#                                                 media  is_opinion  \
# 0   https://scx2.b-cdn.net/gfx/news/hires/2023/chi...       False
# 1   https://i0.wp.com/www.eurasiareview.com/wp-con...       False
# 2   https://d3lzcn6mbbadaf.cloudfront.net/media/de...       False
# 3   https://static.bignewsnetwork.com/bnn/images/b...       False
# 4   https://www.devdiscourse.com/remote.axd?https:...       False
# ..                                                ...         ...
# 64  https://cdn.cfr.org/sites/default/files/styles...       False
# 65  https://thediplomat.com/wp-content/uploads/202...       False
# 66  https://thediplomat.com/wp-content/uploads/202...       False
# 67  https://static.techspot.com/images2/news/bigim...       False
# 68  https://thehill.com/sites/default/files/5gchin...        True
#
#     twitter_account     _score                               _id
# 0              None  38.954735  7e7377c897e2dde021a6bd81b5068cdf
# 1              None  23.516417  451cdf0894a868e2b926ee41063f7419
# 2              @ANI  25.546396  3b347e6be730f336de7896d7d5d1f6d0
# 3   @BigNewsNetwork  26.502396  90a9791130e60049bf9f211c94a4de61
# 4    @dev_discourse  26.582048  49b433ae372e95202ab3d521c96a824d
# ..              ...        ...                               ...
# 64         @CFR_org  44.625183  89c5be6398de2cb01828fff0929544ee
# 65             None  42.865353  81bcb48fb068dfc68ec4913c417baf95
# 66             None  32.889380  afe66583a5b3a536980c52e2ae9a296a
# 67             None  25.128931  7d692a0bad45e926562ea4ec4995f2fe
# 68             None  32.885880  e2d44ac01e79c0bab7244da5824c80c5
#
# [69 rows x 19 columns]

# %%
# Variable to store all found news articles, mp stands for "multiple queries"
all_news_articles_mp = []

# Infinite loop which ends when all articles are extracted
for separated_param in params:

    print(f'Query in use => {str(separated_param)}')
    
    while True:
        # Wait for 1 second between each call
        time.sleep(1)

        # GET Call from previous section enriched with some logs
        response = requests.get(base_url, headers=headers, params=separated_param)
        results = json.loads(response.text.encode())
        if response.status_code == 200:
            print(f'Done for page number => {separated_param["page"]}')


            # Adding your parameters to each result to be able to explore afterwards
            for i in results['articles']:
                i['used_params'] = str(separated_param)


            # Storing all found articles
            all_news_articles_mp.extend(results['articles'])

            # Ensuring to cover all pages by incrementing "page" value at each iteration
            separated_param['page'] += 1
            if separated_param['page'] > results['total_pages']:
                print("All articles have been extracted")
                break
            else:
                print(f'Proceed extracting page number => {separated_param["page"]}')
        else:
            print(results)
            print(f'ERROR: API call failed for page number => {separated_param["page"]}')
            break

print(f'Number of extracted articles => {str(len(all_news_articles_mp))}')
# Out:
# Done for page number => 1
# All articles have been extracted
# Number of extracted articles => 69

# %%
# Define variables
unique_ids = []
all_news_articles = []

# Iterate on each article and check whether we saw this _id before
for article in all_news_articles_mp:
    if article['_id'] not in unique_ids:
        unique_ids.append(article['_id'])
        all_news_articles.append(article)

# %%
# Generate CSV from Pandas table
# Create Pandas table
pandas_table = pd.DataFrame(all_news_articles)

# Generate CSV
pandas_table.to_csv('extracted_news_articles.csv', encoding='utf-8', sep=';')

# %%
pip install python-Levenshtein
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting python-Levenshtein
#   Downloading python_Levenshtein-0.21.1-py3-none-any.whl (9.4 kB)
# Collecting Levenshtein==0.21.1
#   Downloading Levenshtein-0.21.1-cp39-cp39-macosx_11_0_arm64.whl (98 kB)
#      |████████████████████████████████| 98 kB 4.9 MB/s eta 0:00:01
# Collecting rapidfuzz<4.0.0,>=2.3.0
#   Downloading rapidfuzz-3.2.0-cp39-cp39-macosx_11_0_arm64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 18.2 MB/s eta 0:00:01
# Installing collected packages: rapidfuzz, Levenshtein, python-Levenshtein
# Successfully installed Levenshtein-0.21.1 python-Levenshtein-0.21.1 rapidfuzz-3.2.0
# WARNING: You are using pip version 21.2.4; however, version 23.2.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import Levenshtein
# Function to remove approximate duplicates from a DataFrame
def remove_approx_duplicates(df, column_name, threshold=3):
    cleaned_df = pd.DataFrame(columns=df.columns)
    for _, row in df.iterrows():
        is_duplicate = False
        for index, cleaned_row in cleaned_df.iterrows():
            distance = Levenshtein.distance(row[column_name], cleaned_row[column_name])
            if distance <= threshold:
                is_duplicate = True
                break
        if not is_duplicate:
            cleaned_df = cleaned_df.append(row)
    return cleaned_df

# Remove approximate duplicates based on the "title" column
cleaned_df = remove_approx_duplicates(df, column_name="title")

# Print the cleaned DataFrame
print(cleaned_df)
